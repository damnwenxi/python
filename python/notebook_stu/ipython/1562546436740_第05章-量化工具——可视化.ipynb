# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set_context(rc={'figure.figsize': (14, 7) } )
figzize_me = figsize =(14, 7)
# import warnings; 
# warnings.filterwarnings('ignore')

import os
import sys

# %%
print(sys.version)
# Out:
# 3.7.1 (v3.7.1:260ec2c36a, Oct 20 2018, 03:13:28)
# [Clang 6.0 (clang-600.0.57)]

# %%
from abupy import ABuSymbolPd
tsla_df=ABuSymbolPd.make_kl_df('TSLA',n_folds=2)
tsla_df
# Out:
#              close     high      low  p_change    open  pre_close    volume  \
# 2017-07-10  316.05  317.940  303.130     0.904  312.90     313.22  13820889
# 2017-07-11  327.22  327.280  314.300     3.534  316.00     316.05  11559402
# 2017-07-12  329.34  333.000  324.500     0.648  331.20     327.22  10346127
# 2017-07-13  323.41  331.600  319.970    -1.801  330.11     329.34   8594466
# 2017-07-14  327.78  328.420  321.220     1.351  323.19     323.41   5625211
# 2017-07-17  319.57  327.100  313.450    -2.505  325.54     327.78   9876912
# 2017-07-18  328.24  329.130  315.660     2.713  317.50     319.57   6373720
# 2017-07-19  325.26  331.650  323.219    -0.908  328.23     328.24   6357014
# 2017-07-20  329.92  330.220  324.200     1.433  326.90     325.26   5166188
# 2017-07-21  328.40  331.258  325.800    -0.461  329.46     329.92   4901606
# ...            ...      ...      ...       ...     ...        ...       ...
# 2018-12-17  348.42  365.700  343.880    -4.728  362.00     365.71   7674008
# 2018-12-18  337.03  351.550  333.690    -3.269  350.54     348.42   7099999
# 2018-12-19  332.97  347.010  329.740    -1.205  337.60     337.03   8274181
# 2018-12-20  315.38  330.290  311.869    -5.283  327.05     332.97   9071858
# 2018-12-21  319.77  323.470  312.440     1.392  317.40     315.38   8016801
# 2018-12-24  295.39  314.500  295.195    -7.624  313.50     319.77   5559913
# 2018-12-26  326.09  326.970  294.090    10.393  300.00     295.39   8163138
# 2018-12-27  326.09  326.970  294.090     0.000  300.00     326.09   8163138
# 2018-12-28  326.09  326.970  294.090     0.000  300.00     326.09   8163138
# 2018-12-31  326.09  326.970  294.090     0.000  300.00     326.09   8163138
#
#                 date  date_week  key    atr21    atr14
# 2017-07-10  20170710          0    0  14.8100  14.8100
# 2017-07-11  20170711          1    1  14.4171  14.4082
# 2017-07-12  20170712          2    2  15.3431  15.3792
# 2017-07-13  20170713          3    3  14.2782  14.2322
# 2017-07-14  20170714          4    4  12.8014  12.6375
# 2017-07-17  20170717          0    5  12.9785  12.8718
# 2017-07-18  20170718          1    6  13.0703  12.9979
# 2017-07-19  20170719          2    7  12.9015  12.8183
# 2017-07-20  20170720          3    8  11.8152  11.5666
# 2017-07-21  20170721          4    9  10.9546  10.5909
# ...              ...        ...  ...      ...      ...
# 2018-12-17  20181217          0  363  16.2780  16.4044
# 2018-12-18  20181218          1  364  17.7091  18.4865
# 2018-12-19  20181219          2  365  17.7973  18.5123
# 2018-12-20  20181220          3  366  18.4668  19.3988
# 2018-12-21  20181221          4  367  18.6543  19.5496
# 2018-12-24  20181224          0  368  18.7935  19.6343
# 2018-12-26  20181226          2  369  20.0741  21.4004
# 2018-12-27  20181227          3  370  21.2382  22.9310
# 2018-12-28  20181228          4  371  22.2966  24.2575
# 2018-12-31  20181231          0  372  23.2587  25.4072
#
# [373 rows x 12 columns]

# %%
def plot_demo(axs=None,just_series=False):
#     axs子画布
#     just_series是否只画一条
    drawer = axs if axs else plt
    drawer.plot(tsla_df.close,"r")
    if not just_series:
        drawer.plot(tsla_df.close.index,tsla_df.close.values+10,"g")
        drawer.plot(tsla_df.close.index.tolist(),(tsla_df.close.values+20).tolist(),'b')
        plt.xlabel('time')
        plt.ylabel('close')
        plt.title('tesla close')
        
plot_demo()

# %% [markdown]
# # 第5章 量化工具-可视化

# %% [markdown]
# ## 5.1 使用matplotlib可视化数据

# %% [markdown]
# ### 5.1.1 matplotlib可视化基础

# %% [markdown]
# ### 5.1.2 matplotlib子画布及loc的使用

# %% [markdown]
# ### 5.1.3 k线图的绘制

# %% [markdown]
# ## 5.2 使用bokeh交互可视化

# %% [markdown]
# ## 5.3 使用pandas可视化数据
# ### 5.3.1 绘制股票的收益，及收益波动情况

# %% [markdown]
# ### 5.3.2 绘制股票的价格与均线

# %% [markdown]
# ### 5.3.3 其它pandas统计图形种类

# %% [markdown]
# ## 5.4 使用seaborn可视化数据

# %% [markdown]
# ## 5.5 实例1:可视化量化策略的交易区间，卖出原因

# %% [markdown]
# ## 5.6 实例2:标准化两个股票的观察周期

# %% [markdown]
# ## 5.7 综合实例3:黄金分割线

# %% [markdown]
# ### 5.7.1 黄金分割线的定义方式

# %% [markdown]
# ### 5.7.2 多维数据绘制示例

# %% [markdown]
# ## 5.8 技术指标的可视化
#
# ### 5.8.1 MACD指标的可视化

# %% [markdown]
# ### 5.8.2 ATR指标的可视化
