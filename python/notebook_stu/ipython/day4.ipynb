# %%
import pandas as pd
import numpy as np

stock_cnt = 200
stock_days = 504

stock_change = np.random.standard_normal((stock_cnt,stock_days))
stock_change
# Out:
# array([[-0.97707725, -1.4062362 , -0.31699519, ...,  0.24191178,
#         -0.68411275, -1.98831769],
#        [ 1.76302444, -0.34350995, -1.63094564, ..., -0.53051167,
#          1.12077116, -1.45121313],
#        [ 1.01768436,  1.11165719,  0.19457789, ...,  0.47929404,
#          2.04763619, -0.60236363],
#        ...,
#        [ 0.52017591,  0.61768666,  1.59060769, ..., -0.67123141,
#          0.90434075,  1.18523302],
#        [ 2.30130338,  0.43900583,  0.20479598, ..., -0.22135874,
#         -1.93293976,  1.15152344],
#        [ 2.5783704 , -0.88935031,  0.94573939, ..., -0.70220261,
#         -0.76784868,  1.57671205]])

# %%
pd.DataFrame(stock_change)
# Out:
#           0         1         2         3         4         5         6    \
# 0   -0.977077 -1.406236 -0.316995 -0.468249  0.375068  0.521634 -0.336680
# 1    1.763024 -0.343510 -1.630946  0.854595  0.509315  1.649207 -0.628940
# 2    1.017684  1.111657  0.194578  0.376355  0.006831  0.109324  0.361731
# 3    0.549039 -0.201328 -0.751882 -0.369740  0.561009 -0.673452 -1.058158
# 4   -0.071299  0.519788  2.222515  0.932754  0.858486  1.430582  1.777014
# 5    0.181710  1.410775 -1.174006  0.126703 -0.523589 -0.831325  0.338107
# 6   -0.404185  1.178367 -0.237160 -1.217782 -0.346561  0.621093  0.606958
# 7   -0.783737  0.436563  0.350409  0.146314 -1.352326  0.210901  0.537520
# 8   -0.426543  0.450361  0.248855 -0.120366  1.488702 -0.915888  1.304353
# 9   -0.192224 -1.766813  1.091937  1.175266 -0.181970  0.081537  0.416532
# 10   0.301266  0.126547 -1.677726 -1.296532  0.998945  1.099190  1.499233
# 11  -1.669714 -0.818511 -2.149896 -1.175785  1.735494 -0.155634 -1.004917
# ...

# %%
pd.DataFrame(stock_change).tail()
# Out:
#           0         1         2         3         4         5         6    \
# 195  0.110661 -1.337769  1.812113 -0.055175 -0.636680  1.365397 -0.502385
# 196  0.503831  0.533350 -1.346364  0.784763 -0.567769 -0.815051  0.231870
# 197  0.520176  0.617687  1.590608 -0.425197 -1.567037  0.371211  0.486829
# 198  2.301303  0.439006  0.204796  0.709201 -0.912919 -0.084341 -2.078023
# 199  2.578370 -0.889350  0.945739 -0.394025 -1.225960 -0.207746  0.019135
#
#           7         8         9    ...       494       495       496  \
# 195  0.261551  0.416171 -1.235113  ... -0.973385  1.336719 -0.644779
# 196 -0.568632 -0.093710  0.722411  ... -0.089225  0.669085  0.902903
# 197  0.781008  1.003882  1.131672  ...  0.631228  0.481945  0.138371
# 198  0.168257 -0.007006 -0.036756  ...  0.799918 -1.260751  1.694695
# 199 -1.263635  0.927024 -0.833272  ...  0.970846 -0.614795 -0.475973
#
#           497       498       499       500       501       502       503
# ...

# %%
pd.DataFrame(stock_change).head()
# Out:
#         0         1         2         3         4         5         6    \
# 0 -0.977077 -1.406236 -0.316995 -0.468249  0.375068  0.521634 -0.336680
# 1  1.763024 -0.343510 -1.630946  0.854595  0.509315  1.649207 -0.628940
# 2  1.017684  1.111657  0.194578  0.376355  0.006831  0.109324  0.361731
# 3  0.549039 -0.201328 -0.751882 -0.369740  0.561009 -0.673452 -1.058158
# 4 -0.071299  0.519788  2.222515  0.932754  0.858486  1.430582  1.777014
#
#         7         8         9    ...       494       495       496       497  \
# 0 -0.594910 -0.578931 -1.869629  ... -0.787738 -0.621812  0.014587 -0.761852
# 1 -0.721560 -0.083808  0.252335  ... -1.447955 -0.063423  1.106881  0.321843
# 2 -0.200885  0.451193  0.314434  ...  0.702192 -0.701262 -1.304723 -1.031053
# 3  0.497457 -1.112273 -0.934216  ... -0.494259  1.221285  0.528154  0.802948
# 4 -1.268994 -0.274249  0.360207  ...  1.347011  0.044986 -1.628578 -0.538076
#
#         498       499       500       501       502       503
# ...

# %%
pd.DataFrame(stock_change)[5:10]
# Out:
#         0         1         2         3         4         5         6    \
# 5  0.181710  1.410775 -1.174006  0.126703 -0.523589 -0.831325  0.338107
# 6 -0.404185  1.178367 -0.237160 -1.217782 -0.346561  0.621093  0.606958
# 7 -0.783737  0.436563  0.350409  0.146314 -1.352326  0.210901  0.537520
# 8 -0.426543  0.450361  0.248855 -0.120366  1.488702 -0.915888  1.304353
# 9 -0.192224 -1.766813  1.091937  1.175266 -0.181970  0.081537  0.416532
#
#         7         8         9    ...       494       495       496       497  \
# 5 -0.963917  0.349029 -0.338996  ...  2.176180  1.814425 -0.937603  0.815632
# 6 -0.747132  2.411870  0.423680  ... -0.213587 -0.047791  0.558331  1.716880
# 7  1.374095  0.938122 -0.430431  ...  1.630592  0.429716 -1.040981  0.534979
# 8 -0.353492 -0.433086 -0.097496  ... -1.948539  0.276927  0.324262 -0.397382
# 9  0.035774 -1.124871  0.158155  ...  0.114364 -0.122488  0.558372  1.402566
#
#         498       499       500       501       502       503
# ...

# %% [markdown]
# ## 索引行序列

# %%
index = ['TeslaD'+str(i+1) for i in range(stock_change.shape[0])]
index
# Out:
# ['TeslaD1',
#  'TeslaD2',
#  'TeslaD3',
#  'TeslaD4',
#  'TeslaD5',
#  'TeslaD6',
#  'TeslaD7',
#  'TeslaD8',
#  'TeslaD9',
#  'TeslaD10',
#  'TeslaD11',
#  'TeslaD12',
#  'TeslaD13',
#  'TeslaD14',
#  'TeslaD15',
#  'TeslaD16',
#  'TeslaD17',
#  'TeslaD18',
#  'TeslaD19',
#  'TeslaD20',
#  'TeslaD21',
#  'TeslaD22',
#  'TeslaD23',
#  'TeslaD24',
#  'TeslaD25',
#  'TeslaD26',
#  'TeslaD27',
#  'TeslaD28',
#  'TeslaD29',
#  'TeslaD30',
#  'TeslaD31',
#  'TeslaD32',
#  'TeslaD33',
#  'TeslaD34',
#  'TeslaD35',
#  'TeslaD36',
#  'TeslaD37',
#  'TeslaD38',
#  'TeslaD39',
#  'TeslaD40',
#  'TeslaD41',
#  'TeslaD42',
#  'TeslaD43',
#  'TeslaD44',
#  'TeslaD45',
#  'TeslaD46',
#  'TeslaD47',
#  'TeslaD48',
#  'TeslaD49',
#  'TeslaD50',
#  'TeslaD51',
#  'TeslaD52',
#  'TeslaD53',
#  'TeslaD54',
#  'TeslaD55',
#  'TeslaD56',
#  'TeslaD57',
#  'TeslaD58',
#  'TeslaD59',
#  'TeslaD60',
#  'TeslaD61',
#  'TeslaD62',
#  'TeslaD63',
#  'TeslaD64',
#  'TeslaD65',
#  'TeslaD66',
#  'TeslaD67',
# ...

# %%
stock_change.shape
# Out:
# (200, 504)

# %%
pd.DataFrame(stock_change,index=index)
# Out:
#                 0         1         2         3         4         5    \
# TeslaD1   -0.977077 -1.406236 -0.316995 -0.468249  0.375068  0.521634
# TeslaD2    1.763024 -0.343510 -1.630946  0.854595  0.509315  1.649207
# TeslaD3    1.017684  1.111657  0.194578  0.376355  0.006831  0.109324
# TeslaD4    0.549039 -0.201328 -0.751882 -0.369740  0.561009 -0.673452
# TeslaD5   -0.071299  0.519788  2.222515  0.932754  0.858486  1.430582
# TeslaD6    0.181710  1.410775 -1.174006  0.126703 -0.523589 -0.831325
# TeslaD7   -0.404185  1.178367 -0.237160 -1.217782 -0.346561  0.621093
# TeslaD8   -0.783737  0.436563  0.350409  0.146314 -1.352326  0.210901
# TeslaD9   -0.426543  0.450361  0.248855 -0.120366  1.488702 -0.915888
# TeslaD10  -0.192224 -1.766813  1.091937  1.175266 -0.181970  0.081537
# TeslaD11   0.301266  0.126547 -1.677726 -1.296532  0.998945  1.099190
# TeslaD12  -1.669714 -0.818511 -2.149896 -1.175785  1.735494 -0.155634
# ...

# %%
## pandas生成时间
## freq 频率，生成时间间隔 1d表示一天
date_colums = pd.date_range('2016-01-1',periods=stock_change.shape[1],freq='1d')

# %%
pd.DataFrame(stock_change,index=index,columns=date_colums)
# Out:
#            2016-01-01  2016-01-02  2016-01-03  2016-01-04  2016-01-05  \
# TeslaD1     -0.977077   -1.406236   -0.316995   -0.468249    0.375068
# TeslaD2      1.763024   -0.343510   -1.630946    0.854595    0.509315
# TeslaD3      1.017684    1.111657    0.194578    0.376355    0.006831
# TeslaD4      0.549039   -0.201328   -0.751882   -0.369740    0.561009
# TeslaD5     -0.071299    0.519788    2.222515    0.932754    0.858486
# TeslaD6      0.181710    1.410775   -1.174006    0.126703   -0.523589
# TeslaD7     -0.404185    1.178367   -0.237160   -1.217782   -0.346561
# TeslaD8     -0.783737    0.436563    0.350409    0.146314   -1.352326
# TeslaD9     -0.426543    0.450361    0.248855   -0.120366    1.488702
# TeslaD10    -0.192224   -1.766813    1.091937    1.175266   -0.181970
# TeslaD11     0.301266    0.126547   -1.677726   -1.296532    0.998945
# TeslaD12    -1.669714   -0.818511   -2.149896   -1.175785    1.735494
# ...

# %%
df = pd.DataFrame(stock_change,index=index,columns=date_colums)

# %%
df
# Out:
#            2016-01-01  2016-01-02  2016-01-03  2016-01-04  2016-01-05  \
# TeslaD1     -0.977077   -1.406236   -0.316995   -0.468249    0.375068
# TeslaD2      1.763024   -0.343510   -1.630946    0.854595    0.509315
# TeslaD3      1.017684    1.111657    0.194578    0.376355    0.006831
# TeslaD4      0.549039   -0.201328   -0.751882   -0.369740    0.561009
# TeslaD5     -0.071299    0.519788    2.222515    0.932754    0.858486
# TeslaD6      0.181710    1.410775   -1.174006    0.126703   -0.523589
# TeslaD7     -0.404185    1.178367   -0.237160   -1.217782   -0.346561
# TeslaD8     -0.783737    0.436563    0.350409    0.146314   -1.352326
# TeslaD9     -0.426543    0.450361    0.248855   -0.120366    1.488702
# TeslaD10    -0.192224   -1.766813    1.091937    1.175266   -0.181970
# TeslaD11     0.301266    0.126547   -1.677726   -1.296532    0.998945
# TeslaD12    -1.669714   -0.818511   -2.149896   -1.175785    1.735494
# ...

# %%
df = df.T

# %%
#采样，每隔21天采样一次
df_21=df.resample('21D',how='mean')
df_21.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).mean()
#              TeslaD1   TeslaD2   TeslaD3   TeslaD4   TeslaD5   TeslaD6  \
# 2016-01-01 -0.552305 -0.169695  0.192809 -0.021774  0.072278 -0.245273
# 2016-01-22 -0.145213  0.017762 -0.041419 -0.002687 -0.123013 -0.359962
# 2016-02-12  0.401048  0.571055  0.129537  0.045719 -0.325231  0.182102
# 2016-03-04  0.106125  0.279518 -0.173007 -0.094044  0.152119 -0.404336
# 2016-03-25  0.088286  0.305190  0.087270 -0.292404 -0.177384 -0.603691
#
#              TeslaD7   TeslaD8   TeslaD9  TeslaD10  ...  TeslaD191  TeslaD192  \
# 2016-01-01 -0.066660  0.163925  0.061225  0.146283  ...  -0.320578   0.092460
# 2016-01-22 -0.143092  0.081886  0.266081  0.200543  ...  -0.261181  -0.336614
# 2016-02-12 -0.053666  0.300065  0.084885  0.304585  ...  -0.169104  -0.067818
# ...

# %%
df['TeslaD1'].plot()
df['TeslaD2'].plot()

# %%
df['TeslaD5']
# Out:
# 2016-01-01   -0.071299
# 2016-01-02    0.519788
# 2016-01-03    2.222515
# 2016-01-04    0.932754
# 2016-01-05    0.858486
# 2016-01-06    1.430582
# 2016-01-07    1.777014
# 2016-01-08   -1.268994
# 2016-01-09   -0.274249
# 2016-01-10    0.360207
# 2016-01-11   -1.243341
# 2016-01-12    0.218112
# 2016-01-13   -1.586694
# 2016-01-14    1.582074
# 2016-01-15   -0.094339
# 2016-01-16   -1.976441
# 2016-01-17    1.179178
# 2016-01-18   -0.927684
# 2016-01-19   -0.803906
# 2016-01-20    0.572888
# 2016-01-21   -1.888812
# 2016-01-22   -1.299477
# 2016-01-23   -0.200755
# 2016-01-24    0.340594
# 2016-01-25   -1.443983
# 2016-01-26   -0.147392
# 2016-01-27   -0.154546
# 2016-01-28    0.497544
# 2016-01-29   -0.075292
# 2016-01-30    0.536877
#                 ...
# 2017-04-19   -0.197949
# 2017-04-20    0.777941
# 2017-04-21    0.321975
# 2017-04-22   -1.066106
# 2017-04-23   -0.449509
# 2017-04-24   -1.267176
# 2017-04-25   -0.264430
# 2017-04-26    0.490939
# 2017-04-27    2.428189
# ...

# %%
from abupy import ABuSymbolPd
tsla_df=ABuSymbolPd.make_kl_df('TSLA',n_folds=2)
tsla_df
# Out:
#              close     high      low  p_change    open  pre_close    volume  \
# 2017-07-10  316.05  317.940  303.130     0.904  312.90     313.22  13820889
# 2017-07-11  327.22  327.280  314.300     3.534  316.00     316.05  11559402
# 2017-07-12  329.34  333.000  324.500     0.648  331.20     327.22  10346127
# 2017-07-13  323.41  331.600  319.970    -1.801  330.11     329.34   8594466
# 2017-07-14  327.78  328.420  321.220     1.351  323.19     323.41   5625211
# 2017-07-17  319.57  327.100  313.450    -2.505  325.54     327.78   9876912
# 2017-07-18  328.24  329.130  315.660     2.713  317.50     319.57   6373720
# 2017-07-19  325.26  331.650  323.219    -0.908  328.23     328.24   6357014
# 2017-07-20  329.92  330.220  324.200     1.433  326.90     325.26   5166188
# 2017-07-21  328.40  331.258  325.800    -0.461  329.46     329.92   4901606
# ...            ...      ...      ...       ...     ...        ...       ...
# ...

# %%
tsla_df[['close','volume']].plot(subplots=True,
                                 style=['r','g'],grid=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1229ddcc0>,
# ...
#       dtype=object)
